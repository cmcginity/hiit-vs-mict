# %% [markdown]
# # Notebook for configuring access to Google Drive, and looking at Polar H10 workout data!

# %% [markdown]
# ## Set up Google Drive connection
#
# We are using a special "Service Account" to access Google Drive. To access Google Drive, yo
# u need to do two things:
# 1. You will store this service account credential (a json file - ask Aubrey for it) on your computer. Input the path name below as *credentials_path.*
# 2. Replace the *folder_id* with the end of the web URL for the folder on Google Drive you are interested in exploring.
#
# The example below is for accessing Polar H10 workout data stored in Google Drive. Data was obtained from participant exports after study completion.

# %%
import io
import pandas as pd


# Import packages for connecting to Google Drive
from google.oauth2 import service_account
from googleapiclient.discovery import build
# from googleapiclient.errors import HttpError
# from googleapiclient.http import MediaIoBaseDownload

# CHANGE PATH NAME to where the service account credential is on your computer.
credentials_path = '/Users/imogengardiner/Documents/exercise_credential.json'

# REPLACE FOLDER_ID with the folder in Google Drive you are interested in importing data from.
    # Instructions: Search online for the HIIT and Endurance Study shared google drive. Navigate to the folder with data you are interested in. 
    # Look at the web URL. Replace 'folder_id' with the end of the URL.
    # Example for getting Polar Data: HIIT and Endurance Study Drive > Data > data > workout folder. The workout folder URL is https://drive.google.com/drive/folders/1a9Bmg89_9m9BaYLsLw52PS_m07FQ7CtZ.
    # Notice how the end of the web URL is the folder_id.
folder_id = '1a9Bmg89_9m9BaYLsLw52PS_m07FQ7CtZ'

# Authenticate with Google Drive using service account credentials
credentials = service_account.Credentials.from_service_account_file(credentials_path, scopes=['https://www.googleapis.com/auth/drive'])
drive_service = build('drive', 'v3', credentials=credentials)

# Get files
def get_file_ids_from_dir(parent_id):
    # drive_service = setup_drive()
    results = drive_service.files().list(
        corpora='drive',
        driveId='0AB6End4Uf7P-Uk9PVA', # if you search for the HIIT and Endurance Study shared google drive, this ID is taken from the end of the pathname: https://drive.google.com/drive/folders/0AB6End4Uf7P-Uk9PVA
        q=f"'{parent_id}' in parents",
        includeItemsFromAllDrives=True,
        supportsAllDrives=True
    ).execute()
    files = results.get('files', [])
    if not files:
        raise Exception(f"Folder {parent_id} has no files!")
    # id_name = [{x['name'] : x['id']} for x in files]
    id_name = {}
    for x in files:
        id_name[x['name']] = x['id']
    return id_name

def load_data_from_drive(_drive_service, file_id):
    request = _drive_service.files().get_media(fileId=file_id)
    io_buffer = io.BytesIO()
    downloader = MediaIoBaseDownload(io_buffer, request)
    done = False
    while done is False:
        status, done = downloader.next_chunk()
    io_buffer.seek(0)
    df = pd.read_csv(io_buffer, parse_dates=['_realtime','_time'])
    # df = df[df['value'] >= 0.8 * df['target_hr_45']]
    return df

# Get file names from folder
fileids = get_file_ids_from_dir(folder_id)

# Print the files names from the folder
# print(fileids)

df_sl = load_data_from_drive(drive_service, fileids['018_qtz1b19261322566215748_workout_allevents.csv'])
dfsl_list = []
for fname, fid in fileids.items():
    dfsl = load_data_from_drive(drive_service, fid)
    dfsl_list.append(dfsl)

# %%
dfsl_list
# Out:
# [        value               _realtime                    _time  ppt_id  wk_id  \
#  0        75.0 2023-05-01 14:07:32.578  2023-05-01 14:07:32.578       6      1
#  1        75.0 2023-05-01 14:07:33.578  2023-05-01 14:07:33.578       6      1
#  2        76.0 2023-05-01 14:07:34.578  2023-05-01 14:07:34.578       6      1
#  3        76.0 2023-05-01 14:07:35.578  2023-05-01 14:07:35.578       6      1
#  4        78.0 2023-05-01 14:07:36.578  2023-05-01 14:07:36.578       6      1
#  ...       ...                     ...                      ...     ...    ...
#  704908  121.0 2023-09-09 21:52:50.246  2023-09-09 21:52:50.246      19     10
#  704909  120.0 2023-09-09 21:52:51.246  2023-09-09 21:52:51.246      19     10
#  704910  120.0 2023-09-09 21:52:52.246  2023-09-09 21:52:52.246      19     10
#  704911  119.0 2023-09-09 21:52:53.246  2023-09-09 21:52:53.246      19     10
#  704912  119.0 2023-09-09 21:52:54.246  2023-09-09 21:52:54.246      19     10
#
#          wo_id datatype     sourcetype device                myphd_id
#  0           1       hr  WearablePolar  Polar  qtz1b13893369732763681
#  1           1       hr  WearablePolar  Polar  qtz1b13893369732763681
#  2           1       hr  WearablePolar  Polar  qtz1b13893369732763681
#  3           1       hr  WearablePolar  Polar  qtz1b13893369732763681
#  4           1       hr  WearablePolar  Polar  qtz1b13893369732763681
#  ...       ...      ...            ...    ...                     ...
#  704908      3       hr  WearablePolar  Polar  qtz1b17236523485537658
#  704909      3       hr  WearablePolar  Polar  qtz1b17236523485537658
#  704910      3       hr  WearablePolar  Polar  qtz1b17236523485537658
#  704911      3       hr  WearablePolar  Polar  qtz1b17236523485537658
#  704912      3       hr  WearablePolar  Polar  qtz1b17236523485537658
#
#  [704913 rows x 10 columns],
#          value               _realtime                    _time  ppt_id  wk_id  \
#  0          75 2023-05-01 14:07:32.578  2023-05-01 14:07:32.578       6      1
#  1          75 2023-05-01 14:07:33.578  2023-05-01 14:07:33.578       6      1
#  2          76 2023-05-01 14:07:34.578  2023-05-01 14:07:34.578       6      1
#  3          76 2023-05-01 14:07:35.578  2023-05-01 14:07:35.578       6      1
#  4          78 2023-05-01 14:07:36.578  2023-05-01 14:07:36.578       6      1
#  ...       ...                     ...                      ...     ...    ...
#  113558     86 2023-07-18 17:46:19.635  2023-07-18 17:46:19.635       6     12
#  113559     86 2023-07-18 17:46:20.635  2023-07-18 17:46:20.635       6     12
#  113560     86 2023-07-18 17:46:21.000      2028-08-16 17:46:21       6     12
#  113561     86 2023-07-18 17:46:21.635  2023-07-18 17:46:21.635       6     12
#  113562     85 2023-07-18 17:46:22.635  2023-07-18 17:46:22.635       6     12
#
#          wo_id datatype      sourcetype  device                myphd_id
#  0           1       hr   WearablePolar   Polar  qtz1b13893369732763681
#  1           1       hr   WearablePolar   Polar  qtz1b13893369732763681
#  2           1       hr   WearablePolar   Polar  qtz1b13893369732763681
#  3           1       hr   WearablePolar   Polar  qtz1b13893369732763681
#  4           1       hr   WearablePolar   Polar  qtz1b13893369732763681
#  ...       ...      ...             ...     ...                     ...
#  113558      2       hr   WearablePolar   Polar  qtz1b13893369732763681
#  113559      2       hr   WearablePolar   Polar  qtz1b13893369732763681
#  113560      2       hr  WearableFitbit  Fitbit  qtz1b13893369732763681
#  113561      2       hr   WearablePolar   Polar  qtz1b13893369732763681
#  113562      2       hr   WearablePolar   Polar  qtz1b13893369732763681
#
#  [113563 rows x 10 columns],
#         value               _realtime                   _time  ppt_id  wk_id  \
#  0         82 2023-06-28 22:27:11.223 2023-06-28 22:27:11.223      21      1
#  1         82 2023-06-28 22:27:12.223 2023-06-28 22:27:12.223      21      1
#  2         81 2023-06-28 22:27:13.223 2023-06-28 22:27:13.223      21      1
#  3         81 2023-06-28 22:27:14.223 2023-06-28 22:27:14.223      21      1
#  4         81 2023-06-28 22:27:15.223 2023-06-28 22:27:15.223      21      1
#  ...      ...                     ...                     ...     ...    ...
#  46897    134 2023-09-08 21:59:16.869 2023-09-08 21:59:16.869      21     11
#  46898    134 2023-09-08 21:59:17.869 2023-09-08 21:59:17.869      21     11
#  46899    134 2023-09-08 21:59:18.869 2023-09-08 21:59:18.869      21     11
#  46900    134 2023-09-08 21:59:19.869 2023-09-08 21:59:19.869      21     11
#  46901    134 2023-09-08 21:59:20.869 2023-09-08 21:59:20.869      21     11
#
#         wo_id datatype     sourcetype device                myphd_id
#  0          1       hr  WearablePolar  Polar  qtz1b16327775253853113
#  1          1       hr  WearablePolar  Polar  qtz1b16327775253853113
#  2          1       hr  WearablePolar  Polar  qtz1b16327775253853113
#  3          1       hr  WearablePolar  Polar  qtz1b16327775253853113
#  4          1       hr  WearablePolar  Polar  qtz1b16327775253853113
#  ...      ...      ...            ...    ...                     ...
#  46897      3       hr  WearablePolar  Polar  qtz1b16327775253853113
#  46898      3       hr  WearablePolar  Polar  qtz1b16327775253853113
#  46899      3       hr  WearablePolar  Polar  qtz1b16327775253853113
#  46900      3       hr  WearablePolar  Polar  qtz1b16327775253853113
#  46901      3       hr  WearablePolar  Polar  qtz1b16327775253853113
#
#  [46902 rows x 10 columns],
#         value               _realtime                    _time  ppt_id  wk_id  \
#  0          0 2023-07-02 19:21:44.829  2023-07-02 19:21:44.829      20      1
#  1         98 2023-07-02 19:21:45.829  2023-07-02 19:21:45.829      20      1
#  2         98 2023-07-02 19:21:46.829  2023-07-02 19:21:46.829      20      1
#  3         98 2023-07-02 19:21:47.829  2023-07-02 19:21:47.829      20      1
#  4         98 2023-07-02 19:21:48.829  2023-07-02 19:21:48.829      20      1
#  ...      ...                     ...                      ...     ...    ...
#  32995    133 2023-08-30 20:08:50.289  2023-08-30 20:08:50.289      20      7
#  32996    133 2023-08-30 20:08:51.289  2023-08-30 20:08:51.289      20      7
#  32997    133 2023-08-30 20:08:52.289  2023-08-30 20:08:52.289      20      7
#  32998    132 2023-08-30 20:08:53.289  2023-08-30 20:08:53.289      20      7
#  32999    131 2023-08-30 20:08:54.289  2023-08-30 20:08:54.289      20      7
#
#         wo_id datatype     sourcetype device                myphd_id
#  0          1       hr  WearablePolar  Polar  qtz1b19129928133897239
#  1          1       hr  WearablePolar  Polar  qtz1b19129928133897239
#  2          1       hr  WearablePolar  Polar  qtz1b19129928133897239
#  3          1       hr  WearablePolar  Polar  qtz1b19129928133897239
#  4          1       hr  WearablePolar  Polar  qtz1b19129928133897239
#  ...      ...      ...            ...    ...                     ...
#  32995      3       hr  WearablePolar  Polar  qtz1b19129928133897239
#  32996      3       hr  WearablePolar  Polar  qtz1b19129928133897239
#  32997      3       hr  WearablePolar  Polar  qtz1b19129928133897239
#  32998      3       hr  WearablePolar  Polar  qtz1b19129928133897239
#  32999      3       hr  WearablePolar  Polar  qtz1b19129928133897239
#
#  [33000 rows x 10 columns],
#         value               _realtime                    _time  ppt_id  wk_id  \
#  0        143 2023-07-02 10:12:28.915  2023-07-02 10:12:28.915      19      1
#  1        136 2023-07-02 10:12:29.000      2028-05-21 10:12:29      19      1
#  2        143 2023-07-02 10:12:29.915  2023-07-02 10:12:29.915      19      1
#  3        134 2023-07-02 10:12:30.000      2028-05-21 10:12:30      19      1
#  4        141 2023-07-02 10:12:30.915  2023-07-02 10:12:30.915      19      1
#  ...      ...                     ...                      ...     ...    ...
#  81308    121 2023-09-09 21:52:50.246  2023-09-09 21:52:50.246      19     10
#  81309    120 2023-09-09 21:52:51.246  2023-09-09 21:52:51.246      19     10
#  81310    120 2023-09-09 21:52:52.246  2023-09-09 21:52:52.246      19     10
#  81311    119 2023-09-09 21:52:53.246  2023-09-09 21:52:53.246      19     10
#  81312    119 2023-09-09 21:52:54.246  2023-09-09 21:52:54.246      19     10
#
#         wo_id datatype      sourcetype  device                myphd_id
#  0          1       hr   WearablePolar   Polar  qtz1b17236523485537658
#  1          1       hr  WearableFitbit  Fitbit  qtz1b17236523485537658
#  2          1       hr   WearablePolar   Polar  qtz1b17236523485537658
#  3          1       hr  WearableFitbit  Fitbit  qtz1b17236523485537658
#  4          1       hr   WearablePolar   Polar  qtz1b17236523485537658
#  ...      ...      ...             ...     ...                     ...
#  81308      3       hr   WearablePolar   Polar  qtz1b17236523485537658
#  81309      3       hr   WearablePolar   Polar  qtz1b17236523485537658
#  81310      3       hr   WearablePolar   Polar  qtz1b17236523485537658
#  81311      3       hr   WearablePolar   Polar  qtz1b17236523485537658
#  81312      3       hr   WearablePolar   Polar  qtz1b17236523485537658
#
#  [81313 rows x 10 columns],
#          value           _realtime               _time  ppt_id  wk_id  wo_id  \
#  0       102.0 2023-06-14 18:55:08 2023-06-14 18:55:08      18      1      1
#  1       104.0 2023-06-14 18:55:09 2023-06-14 18:55:09      18      1      1
#  2       106.0 2023-06-14 18:55:10 2023-06-14 18:55:10      18      1      1
#  3       101.0 2023-06-14 18:55:11 2029-07-29 18:55:11      18      1      1
#  4       108.0 2023-06-14 18:55:11 2023-06-14 18:55:11      18      1      1
#  ...       ...                 ...                 ...     ...    ...    ...
#  122804  112.0 2023-09-03 14:58:17 2023-09-03 14:58:17      18     12      3
#  122805  111.0 2023-09-03 14:58:18 2023-09-03 14:58:18      18     12      3
#  122806  111.0 2023-09-03 14:58:19 2023-09-03 14:58:19      18     12      3
#  122807  111.0 2023-09-03 14:58:20 2023-09-03 14:58:20      18     12      3
#  122808  111.0 2023-09-03 14:58:20 2029-10-18 14:58:20      18     12      3
#
#         datatype      sourcetype  device                myphd_id
#  0            hr   WearablePolar   Polar  qtz1b19261322566215748
#  1            hr   WearablePolar   Polar  qtz1b19261322566215748
#  2            hr   WearablePolar   Polar  qtz1b19261322566215748
#  3            hr  WearableFitbit  Fitbit  qtz1b19261322566215748
#  4            hr   WearablePolar   Polar  qtz1b19261322566215748
#  ...         ...             ...     ...                     ...
#  122804       hr   WearablePolar   Polar  qtz1b19261322566215748
#  122805       hr   WearablePolar   Polar  qtz1b19261322566215748
#  122806       hr   WearablePolar   Polar  qtz1b19261322566215748
#  122807       hr   WearablePolar   Polar  qtz1b19261322566215748
#  122808       hr  WearableFitbit  Fitbit  qtz1b19261322566215748
#
#  [122809 rows x 10 columns],
#         value               _realtime                    _time  ppt_id  wk_id  \
#  0          0 2023-06-06 20:33:12.846  2023-06-06 20:33:12.846      14      1
#  1          0 2023-06-06 20:33:13.846  2023-06-06 20:33:13.846      14      1
#  2          0 2023-06-06 20:33:14.846  2023-06-06 20:33:14.846      14      1
#  3          0 2023-06-06 20:33:15.846  2023-06-06 20:33:15.846      14      1
#  4          0 2023-06-06 20:33:16.846  2023-06-06 20:33:16.846      14      1
#  ...      ...                     ...                      ...     ...    ...
#  56947    135 2023-08-27 01:18:06.739  2023-08-27 01:18:06.739      14     12
#  56948    135 2023-08-27 01:18:07.739  2023-08-27 01:18:07.739      14     12
#  56949    135 2023-08-27 01:18:08.739  2023-08-27 01:18:08.739      14     12
#  56950    137 2023-08-27 01:18:09.739  2023-08-27 01:18:09.739      14     12
#  56951    137 2023-08-27 01:18:10.739  2023-08-27 01:18:10.739      14     12
#
#         wo_id datatype     sourcetype device                myphd_id
#  0          1       hr  WearablePolar  Polar  qtz1b13168362397931536
#  1          1       hr  WearablePolar  Polar  qtz1b13168362397931536
#  2          1       hr  WearablePolar  Polar  qtz1b13168362397931536
#  3          1       hr  WearablePolar  Polar  qtz1b13168362397931536
#  4          1       hr  WearablePolar  Polar  qtz1b13168362397931536
#  ...      ...      ...            ...    ...                     ...
#  56947      3       hr  WearablePolar  Polar  qtz1b13168362397931536
#  56948      3       hr  WearablePolar  Polar  qtz1b13168362397931536
#  56949      3       hr  WearablePolar  Polar  qtz1b13168362397931536
#  56950      3       hr  WearablePolar  Polar  qtz1b13168362397931536
#  56951      3       hr  WearablePolar  Polar  qtz1b13168362397931536
#
#  [56952 rows x 10 columns],
#         value               _realtime                    _time  ppt_id  wk_id  \
#  0        104 2023-06-11 09:47:07.325  2023-06-11 09:47:07.325      12      1
#  1        103 2023-06-11 09:47:08.325  2023-06-11 09:47:08.325      12      1
#  2        102 2023-06-11 09:47:09.325  2023-06-11 09:47:09.325      12      1
#  3        102 2023-06-11 09:47:10.325  2023-06-11 09:47:10.325      12      1
#  4        102 2023-06-11 09:47:11.325  2023-06-11 09:47:11.325      12      1
#  ...      ...                     ...                      ...     ...    ...
#  38683    122 2023-07-21 18:37:46.555  2023-07-21 18:37:46.555      12      6
#  38684    121 2023-07-21 18:37:47.555  2023-07-21 18:37:47.555      12      6
#  38685    121 2023-07-21 18:37:48.555  2023-07-21 18:37:48.555      12      6
#  38686    120 2023-07-21 18:37:49.555  2023-07-21 18:37:49.555      12      6
#  38687    119 2023-07-21 18:37:50.555  2023-07-21 18:37:50.555      12      6
#
#         wo_id datatype     sourcetype device                myphd_id
#  0          1       hr  WearablePolar  Polar  qtz1b17269433695528197
#  1          1       hr  WearablePolar  Polar  qtz1b17269433695528197
#  2          1       hr  WearablePolar  Polar  qtz1b17269433695528197
#  3          1       hr  WearablePolar  Polar  qtz1b17269433695528197
#  4          1       hr  WearablePolar  Polar  qtz1b17269433695528197
#  ...      ...      ...            ...    ...                     ...
#  38683      3       hr  WearablePolar  Polar  qtz1b17269433695528197
#  38684      3       hr  WearablePolar  Polar  qtz1b17269433695528197
#  38685      3       hr  WearablePolar  Polar  qtz1b17269433695528197
#  38686      3       hr  WearablePolar  Polar  qtz1b17269433695528197
#  38687      3       hr  WearablePolar  Polar  qtz1b17269433695528197
#
#  [38688 rows x 10 columns],
#         value           _realtime               _time  ppt_id  wk_id  wo_id  \
#  0          0 2023-06-20 18:19:56 2023-06-20 18:19:56      10      1      1
#  1        101 2023-06-20 18:19:56 2030-06-17 18:19:56      10      1      1
#  2        121 2023-06-20 18:19:57 2023-06-20 18:19:57      10      1      1
#  3        121 2023-06-20 18:19:58 2023-06-20 18:19:58      10      1      1
#  4        122 2023-06-20 18:19:59 2023-06-20 18:19:59      10      1      1
#  ...      ...                 ...                 ...     ...    ...    ...
#  63071    129 2023-08-25 09:03:25 2023-08-25 09:03:25      10     10      2
#  63072    129 2023-08-25 09:03:26 2023-08-25 09:03:26      10     10      2
#  63073    129 2023-08-25 09:03:27 2023-08-25 09:03:27      10     10      2
#  63074    129 2023-08-25 09:03:28 2023-08-25 09:03:28      10     10      2
#  63075    130 2023-08-25 09:03:29 2023-08-25 09:03:29      10     10      2
#
#        datatype      sourcetype  device                myphd_id
#  0           hr   WearablePolar   Polar  qtz1b19121547781291613
#  1           hr  WearableFitbit  Fitbit  qtz1b19121547781291613
#  2           hr   WearablePolar   Polar  qtz1b19121547781291613
#  3           hr   WearablePolar   Polar  qtz1b19121547781291613
#  4           hr   WearablePolar   Polar  qtz1b19121547781291613
#  ...        ...             ...     ...                     ...
#  63071       hr   WearablePolar   Polar  qtz1b19121547781291613
#  63072       hr   WearablePolar   Polar  qtz1b19121547781291613
#  63073       hr   WearablePolar   Polar  qtz1b19121547781291613
#  63074       hr   WearablePolar   Polar  qtz1b19121547781291613
#  63075       hr   WearablePolar   Polar  qtz1b19121547781291613
#
#  [63076 rows x 10 columns],
#         value               _realtime                   _time  ppt_id  wk_id  \
#  0        118 2023-06-04 14:50:46.711 2023-06-04 14:50:46.711       5      1
#  1        118 2023-06-04 14:50:47.711 2023-06-04 14:50:47.711       5      1
#  2        117 2023-06-04 14:50:48.711 2023-06-04 14:50:48.711       5      1
#  3        117 2023-06-04 14:50:49.711 2023-06-04 14:50:49.711       5      1
#  4        117 2023-06-04 14:50:50.711 2023-06-04 14:50:50.711       5      1
#  ...      ...                     ...                     ...     ...    ...
#  76566    118 2023-08-24 19:16:07.663 2023-08-24 19:16:07.663       5     12
#  76567    118 2023-08-24 19:16:08.663 2023-08-24 19:16:08.663       5     12
#  76568    117 2023-08-24 19:16:09.663 2023-08-24 19:16:09.663       5     12
#  76569    117 2023-08-24 19:16:10.663 2023-08-24 19:16:10.663       5     12
#  76570    117 2023-08-24 19:16:11.663 2023-08-24 19:16:11.663       5     12
#
#         wo_id datatype     sourcetype device                myphd_id
#  0          1       hr  WearablePolar  Polar  qtz1b16767772887265127
#  1          1       hr  WearablePolar  Polar  qtz1b16767772887265127
#  2          1       hr  WearablePolar  Polar  qtz1b16767772887265127
#  3          1       hr  WearablePolar  Polar  qtz1b16767772887265127
#  4          1       hr  WearablePolar  Polar  qtz1b16767772887265127
#  ...      ...      ...            ...    ...                     ...
#  76566      1       hr  WearablePolar  Polar  qtz1b16767772887265127
#  76567      1       hr  WearablePolar  Polar  qtz1b16767772887265127
#  76568      1       hr  WearablePolar  Polar  qtz1b16767772887265127
#  76569      1       hr  WearablePolar  Polar  qtz1b16767772887265127
#  76570      1       hr  WearablePolar  Polar  qtz1b16767772887265127
#
#  [76571 rows x 10 columns],
#         value               _realtime                   _time  ppt_id  wk_id  \
#  0          0 2023-05-09 13:53:03.148 2023-05-09 13:53:03.148       4      1
#  1         88 2023-05-09 13:53:04.148 2023-05-09 13:53:04.148       4      1
#  2         88 2023-05-09 13:53:05.148 2023-05-09 13:53:05.148       4      1
#  3         89 2023-05-09 13:53:06.148 2023-05-09 13:53:06.148       4      1
#  4         89 2023-05-09 13:53:07.148 2023-05-09 13:53:07.148       4      1
#  ...      ...                     ...                     ...     ...    ...
#  72034    105 2023-08-09 12:29:55.581 2023-08-09 12:29:55.581       4     14
#  72035    103 2023-08-09 12:29:56.581 2023-08-09 12:29:56.581       4     14
#  72036    103 2023-08-09 12:29:57.581 2023-08-09 12:29:57.581       4     14
#  72037    102 2023-08-09 12:29:58.581 2023-08-09 12:29:58.581       4     14
#  72038    102 2023-08-09 12:29:59.581 2023-08-09 12:29:59.581       4     14
#
#         wo_id datatype     sourcetype device                myphd_id
#  0          1       hr  WearablePolar  Polar  qtz1b18445579426718188
#  1          1       hr  WearablePolar  Polar  qtz1b18445579426718188
#  2          1       hr  WearablePolar  Polar  qtz1b18445579426718188
#  3          1       hr  WearablePolar  Polar  qtz1b18445579426718188
#  4          1       hr  WearablePolar  Polar  qtz1b18445579426718188
#  ...      ...      ...            ...    ...                     ...
#  72034      1       hr  WearablePolar  Polar  qtz1b18445579426718188
#  72035      1       hr  WearablePolar  Polar  qtz1b18445579426718188
#  72036      1       hr  WearablePolar  Polar  qtz1b18445579426718188
#  72037      1       hr  WearablePolar  Polar  qtz1b18445579426718188
#  72038      1       hr  WearablePolar  Polar  qtz1b18445579426718188
#
#  [72039 rows x 10 columns]]
